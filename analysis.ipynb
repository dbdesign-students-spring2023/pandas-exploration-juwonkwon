# %% [markdown]
# # pandas exploration
# In this assignment you will select a data set and do some munging and analysis of it using `pandas`, Jupyter Notebooks, and associated Python-centric data science tools.

# %% [markdown]
# Import the core data science libraries:

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## Import the raw data
# In this section, you will import the raw data into a `pandas` DataFrame.

# %%
# place your code into this Code cell
df_listings = pd.read_csv('data/listings.csv')

# %% [markdown]
# ## Data inspection
# In this section, you will show enough of your data for a viewer to get a general sense of how the data is structured and any unique features of it.  Complete each of the indicated tasks in a Code cell, making sure to include a Markdown cell above each Code cell that explains what is being shown by the code.
# - Show 5 rows, selected at random, from the data set.
# - Show each of the column names and their data types.
# - Show any unique features of your chosen data set.
#
# Feel free to add as many additional cells as you need to help explain the raw data.

# %% [markdown]
# 1. Showing 5 rows selected at random.

# %%
df_listings.sample(5)
# Out:
#         id                           listing_url       scrape_id last_scraped
# 0   157612   https://www.airbnb.com/rooms/157612  20230327145459   2023-03-27  \
# 1  1241309  https://www.airbnb.com/rooms/1241309  20230327145459   2023-03-27
# 2  4468181  https://www.airbnb.com/rooms/4468181  20230327145459   2023-03-27
# 3   283495   https://www.airbnb.com/rooms/283495  20230327145459   2023-03-27
# 4  1329093  https://www.airbnb.com/rooms/1329093  20230327145459   2023-03-27
#
#         source                                               name
# 0  city scrape                 New attic space/single & Dble room  \
# 1  city scrape  ★Glass Roof★Walkable★Full Kitch★Office★Deck★Ga...
# 2  city scrape                    Double Room in shared apartment
# 3  city scrape                    En-suite room in detached house
# 4  city scrape                          Private B&B Double Room 2
#
#                                          description
# ...

# %% [markdown]
# 2. show all column names and data types

# %%
df_listings.dtypes
# Out:
# id                                                int64
# listing_url                                      object
# scrape_id                                         int64
# last_scraped                                     object
# source                                           object
#                                                  ...
# calculated_host_listings_count                    int64
# calculated_host_listings_count_entire_homes       int64
# calculated_host_listings_count_private_rooms      int64
# calculated_host_listings_count_shared_rooms       int64
# reviews_per_month                               float64
# Length: 75, dtype: object

# %% [markdown]
# 3. show how many rows, columns are there

# %%
df_listings.shape
# Out:
# (5036, 69)

# %% [markdown]
# ## Data munging
# Place your **data munging** code and documentation within this section.
# - Keep each of your Code cells short and focused on a single task.
# - Include a Markdown cell above each code cell that describes what task the code within the code cell is performing.
# - Make as many code cells as you need to complete the munging - a few have been created for you to start with.
# - Display 5 sample rows of the modified data after each transformation so a viewer can see how the data has changed.
#
# **Note**: If you believe that your data set does not require any munging, please explain in detail.  Create Markdown cells that explain your thinking and create Code cells that show any specific structures of the data you refer to in your explanation.

# %% [markdown]
# Dropped unnecessary columns for data.

# %%
df_listings.drop(['scrape_id', 'last_scraped','listing_url', 'picture_url', 'host_url', 'license'], axis=1, inplace=True)

# %% [markdown]
# dropped all rows with nan values.

# %%
df_listings.dropna()
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# Sample 5 rows

# %%
df_listings.sample(5)
# Out:
#                       id       source
# 1918            50342585  city scrape  \
# 4490  816172677891286758  city scrape
# 4450  815277556228742538  city scrape
# 3790  735961812102373898  city scrape
# 4049  776206377484615968  city scrape
#
#                                                name
# 1918                     Rusholme Rooms Apartment 1  \
# 4490                 Brian Redhead Court Hulme Area
# 4450  The Mitre Hotel Manchester by LookBookHoliday
# 3790   A large unique 6-bedroom house in Altrincham
# 4049    Pet friendly studio for 1. Sale. Manchester
#
#                                             description
# 1918  Rusholme Apartments are situated in the heart ...  \
# 4490  Keep it simple at this peaceful and centrally-...
# 4450  With its grand exterior, The Mitre Hotel has r...
# 3790  I am very excited to welcome guests to my love...
# 4049  You are booking a studio which is a single bed...
#
# ...

# %% [markdown]
# ## Data analysis
# Place your **data analysis** code and documentation within this section.
# - Perform at least 5 different statistical or other analyses of different aspects of the data.
#     - Your analyses must be specific and relevant to your chosen data set and show interesting aspects of it.
#     - Include at least one analysis that includes grouping rows by a shared attribute and performing some kind of statistical analysis on each group.
#     - Sort the data in at least 1 of your analyses, but sort on its own does not constitute an analysis on its own.
# - Keep each of your Code cells short and focused on a single task.
# - Include a Markdown cell above each Code cell that describes what task the code within the Code cell is performing.
# - Make as many code cells as you need to complete the analysis - a few have been created for you to start with.

# %% [markdown]
# 1. show all listings with private rooms greater than 2

# %%
df_listings_private_rooms = df_listings[df_listings['calculated_host_listings_count_private_rooms'] >=2]
# Out:
#          id       source                                               name
# 5   1343251  city scrape                      NICE 2 BEDROOM VICTORIA PARK.  \
# 17  1818864  city scrape                Nice 1 bedroom flat close to Univer
# 19  4635584  city scrape                Modern,spacious, car park,2 toilets
# 25  5158797  city scrape       Twin Bedroom in Victorian home with en suite
# 29  1864263  city scrape  Nice Room. Quiet Houseshare. Near M60 & Train ...
#
#                                           description
# 5   <b>The space</b><br />I have a nice 2 bedroom ...  \
# 17  <b>The space</b><br />Nice flat and close to U...
# 19  This is a nice,clean and modern flat. There is...
# 25  A stylish, quiet and comfortable bedroom in a ...
# 29  If you don't want to pay extra for some cute l...
#
#                                 neighborhood_overview   host_id    host_name
# 5                                                 NaN   4274481         Adel  \
# ...

# %% [markdown]
# 2. show airbnbs that have greater than 4 in rating

# %%
df_review_score = df_listings[df_listings['review_scores_value']>4]
# Out:
#                       id           source
# 3987  768690103610100857      city scrape  \
# 2063            49937409  previous scrape
# 2404            53530017      city scrape
# 3109  626908898298503115      city scrape
# 3410  676539910526389808      city scrape
#
#                                                  name
# 3987                      Ensuite Double with balcony  \
# 2063         IMMACULATE 2-BED APARTMENT IN MANCHESTER
# 2404  Spacious Entire Apartment in Central Manchester
# 3109                               Warm inviting home
# 3410                              Church Street House
#
#                                             description
# 3987  Enjoy easy access to everything from this perf...  \
# 2063  This 2 Bedroom apartment  Is Immaculate ! Offe...
# 2404  Stay in the heart of Central Manchester in thi...
# 3109  My home is a place that accepts me for the per...
# 3410  This modern, self-contained and newly renovate...
#
# ...

# %% [markdown]
# 3. show airbnb sorted by reviews_per_month descending

# %%
df_listings.sort_values(by='reviews_per_month', ascending=False)
# Out:
#                       id       source
# 921             30782781  city scrape  \
# 2798  584689962945222448  city scrape
# 909             32234028  city scrape
# 4019  771093929966410543  city scrape
# 3769  741199115263568903  city scrape
# ...                  ...          ...
# 5031  848840782831461909  city scrape
# 5032  848980812417335000  city scrape
# 5033  849042545651919792  city scrape
# 5034  844327221131428098  city scrape
# 5035  844710414448607894  city scrape
#
#                                                    name
# 921               Whitworth Locke City Studio Apartment  \
# 2798      Stylish 2-Bedroom Townhouse With Free Parking
# 909          Cove Minshull Street One Bedroom Apartment
# 4019     Luxe Studio Apt 》Central 》Private》Parking》WiFi
# 3769                Spacious private room in town house
# ...                                                 ...
# 5031                   1bed Apt in m1 with free parking
# ...

# %% [markdown]
# 4. group airbnb by area

# %%
df_listings.groupby("host_location")['host_location'].count()
# Out:
# host_location
# Abidjan, Côte d’Ivoire            1
# Alderley Edge, United Kingdom     2
# Altrincham, United Kingdom       17
# Arddleen, United Kingdom          2
# Argentina                         1
#                                  ..
# Worsley, United Kingdom           5
# Wraysbury, United Kingdom         1
# Writtle, United Kingdom           1
# Wythenshawe, United Kingdom      25
# Zürich, Switzerland               1
# Name: host_location, Length: 186, dtype: int64

# %% [markdown]
# 5. mean review score of all airbnb grouped by area

# %%
df_area_review = df_listings.groupby("host_location")['review_scores_value'].mean()
df_area_review.sample(5)
# Out:
# host_location
# Walton-le-Dale, United Kingdom    4.930000
# Knutsford, United Kingdom         4.660000
# Droylsden, United Kingdom         4.320000
# Wigan, United Kingdom             4.756923
# Delph, United Kingdom             4.861538
# Name: review_scores_value, dtype: float64

# %% [markdown]
# ## Data visualization
# In this section, you will create a few **visualizations** that show some of the insights you have gathered from this data.
# - Create at least 5 different visualizations, where each visualization shows different insights into the data.
# - Use at least 3 different visualization types (e.g. bar charts, line charts, stacked area charts, pie charts, etc)
# - Create a Markdown cell and a Code cell for each, where you explain and show the visualizations, respectively.
# - Create as many additional cells as you need to prepare the data for the visualizations.

# %% [markdown]
# 1. bar graph of mean review scores per area

# %%
df_area_review.plot(kind='bar', title='review scores by area', ylabel='scores', xlabel='area', figsize=(26,5))
# Out:
# <Axes: title={'center': 'review scores by area'}, xlabel='area', ylabel='scores'>

# %% [markdown]
# ![mean reviews per area bar graph](./images/bar.png)
